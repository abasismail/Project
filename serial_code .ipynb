# %%
# %%writefile evaluate_fitness.py
import numpy as np
import pandas as pd
import sys
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score



chromosome_id = int(sys.argv[1])

# Load dataset (do not drop any columns)
df = pd.read_csv("Crop_recommendation.csv")
X = df.drop(columns="label")  # Ensure all features are included
y = df["label"]

# Read chromosome
chromosome = np.loadtxt("chromosome.txt", delimiter=",", dtype=int)
print(f"Chromosome {chromosome_id}:", chromosome)

# Validate chromosome length
if len(chromosome) != X.shape[1]:
    raise ValueError(f"Chromosome length {len(chromosome)} does not match the number of features {X.shape[1]}")

# Get selected features
selected_features = np.where(chromosome == 1)[0]
print("Selected Features:", selected_features)
print("Dataset Shape:", X.shape)

# Handle case where no features are selected
if len(selected_features) == 0:
    print("No features selected. Exiting...")
    with open("fitness_result.txt", "w") as f:
        f.write("0.0")
    exit()

# Select features based on chromosome
X_selected = X.iloc[:, selected_features]

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.3, random_state=42)

# Train the model
rf = RandomForestClassifier(n_estimators=50, random_state=42, criterion="entropy")
rf.fit(X_train, y_train)

# Predict and calculate accuracy
y_pred = rf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Save fitness result
with open("fitness_result.txt", "w") as f:
    f.write(str(accuracy))
# Out:
# Overwriting evaluate_fitness.py

# %%
# %%writefile main.c
#
#
#
# #include <stdio.h>
# #include <stdlib.h>
# #include <time.h>
#
# #define POP_SIZE 50
# #define CHROMOSOME_LENGTH 7
# #define NUM_GENERATIONS 50
# #define MUTATION_RATE 0.01
# #define MAX_STAGNATION 3 // Maximum allowed generations without improvement
#
# // Individual struct to include ID
# typedef struct {
#     int id;                     // ID of the individual
#     int genes[CHROMOSOME_LENGTH]; // Chromosome (gene array)
#     double fitness;             // Fitness value
# } Individual;
#
# // Function prototypes
# void generate_chromosome(int chromosome[], int length);
# double evaluate_fitness(int chromosome[], int length, int chromosome_id);
# int roulette_wheel_selection(Individual population[], int population_size);
# void three_point_crossover(int parent1[], int parent2[], int offspring1[], int offspring2[], int length);
# void mutate(int chromosome[], int length, double mutation_rate);
#
# int main() {
#     srand(time(NULL));
#
#     Individual population[POP_SIZE];
#
#     // Step 1: Initialize Population (silent initialization)
#     for (int i = 0; i < POP_SIZE; i++) {
#         population[i].id = i + 1; // Assign unique ID
#         generate_chromosome(population[i].genes, CHROMOSOME_LENGTH);
#         population[i].fitness = evaluate_fitness(population[i].genes, CHROMOSOME_LENGTH, population[i].id);
#     }
#
#     double best_fitness = population[0].fitness;
#     int stagnation_count = 0;
#
#     // Genetic Algorithm Loop
#     for (int generation = 0; generation < NUM_GENERATIONS; generation++) {
#         printf("\n=== Generation %d ===\n", generation);
#
#         Individual new_population[POP_SIZE];
#
#         // Step 1: Find the Best Individual
#         double current_best_fitness = population[0].fitness;
#         int best_idx = 0;
#         for (int i = 1; i < POP_SIZE; i++) {
#             if (population[i].fitness > current_best_fitness) {
#                 current_best_fitness = population[i].fitness;
#                 best_idx = i;
#             }
#         }
#
#         // Step 2: Add the Best Individual to the New Population (Elitism)
#         new_population[0] = population[best_idx];
#
#         // Step 3: Generate the Rest of the New Population
#         for (int i = 1; i < POP_SIZE; i += 2) { // Start from 1 to skip the best individual
#             // Selection
#             int parent1_idx = roulette_wheel_selection(population, POP_SIZE);
#             int parent2_idx = roulette_wheel_selection(population, POP_SIZE);
#
#             // Crossover
#             three_point_crossover(
#                 population[parent1_idx].genes, population[parent2_idx].genes,
#                 new_population[i].genes, new_population[i + 1].genes, CHROMOSOME_LENGTH
#             );
#
#             // Mutation
#             mutate(new_population[i].genes, CHROMOSOME_LENGTH, MUTATION_RATE);
#             if (i + 1 < POP_SIZE) { // Avoid out-of-bounds
#                 mutate(new_population[i + 1].genes, CHROMOSOME_LENGTH, MUTATION_RATE);
#             }
#
#             // Evaluate fitness of offspring
#             new_population[i].id = i + 1;
#             if (i + 1 < POP_SIZE) {
#                 new_population[i + 1].id = i + 2;
#                 new_population[i + 1].fitness = evaluate_fitness(new_population[i + 1].genes, CHROMOSOME_LENGTH, new_population[i + 1].id);
#             }
#             new_population[i].fitness = evaluate_fitness(new_population[i].genes, CHROMOSOME_LENGTH, new_population[i].id);
#         }
#
#         // Replace the old population with the new population
#         for (int i = 0; i < POP_SIZE; i++) {
#             population[i] = new_population[i];
#         }
#
#         // Log population for the current generation
#         for (int i = 0; i < POP_SIZE; i++) {
#             printf("Chromosome %d: [", population[i].id);
#             for (int j = 0; j < CHROMOSOME_LENGTH; j++) {
#                 printf("%d", population[i].genes[j]);
#                 if (j < CHROMOSOME_LENGTH - 1) printf(" ");
#             }
#             printf("] Accuracy: %.4f\n", population[i].fitness);
#         }
#
#         printf("Best Fitness in Generation %d: %.4f (ID: %d)\n", generation, current_best_fitness, population[best_idx].id);
#
#         // Step 4: Check for Stagnation
#         if (current_best_fitness == best_fitness) {
#             stagnation_count++;
#             printf("No improvement in generation %d. Stagnation count: %d\n", generation, stagnation_count);
#             if (stagnation_count >= MAX_STAGNATION) {
#                 printf("Stopping early due to stagnation: No improvement for %d generations.\n", MAX_STAGNATION);
#                 break;
#             }
#         } else {
#             best_fitness = current_best_fitness;
#             stagnation_count = 0;
#         }
#     }
#
#     return 0;
# }
#
# void generate_chromosome(int chromosome[], int length) {
#     for (int i = 0; i < length; i++) {
#         chromosome[i] = rand() % 2; // Randomly assign 0 or 1
#     }
# }
#
# double evaluate_fitness(int chromosome[], int length, int chromosome_id) {
#     FILE *file = fopen("chromosome.txt", "w");
#     if (!file) {
#         perror("Error opening chromosome file");
#         exit(EXIT_FAILURE);
#     }
#
#     // Write chromosome to file
#     for (int i = 0; i < length; i++) {
#         fprintf(file, "%d", chromosome[i]);
#         if (i < length - 1) {
#             fprintf(file, ",");
#         }
#     }
#     fclose(file);
#
#     // Pass chromosome ID to Python script
#     char command[256];
#     sprintf(command, "python3 evaluate_fitness.py %d", chromosome_id);
#     if (system(command) != 0) {
#         fprintf(stderr, "Error executing Python script.\n");
#         exit(EXIT_FAILURE);
#     }
#
#     // Read fitness result
#     file = fopen("fitness_result.txt", "r");
#     if (!file) {
#         perror("Error opening fitness result file");
#         exit(EXIT_FAILURE);
#     }
#     double fitness;
#     fscanf(file, "%lf", &fitness);
#     fclose(file);
#
#     return fitness;
# }
#
# int roulette_wheel_selection(Individual population[], int population_size) {
#     double total_fitness = 0.0;
#     for (int i = 0; i < population_size; i++) {
#         total_fitness += population[i].fitness;
#     }
#
#     double cumulative_prob[POP_SIZE];
#     cumulative_prob[0] = population[0].fitness / total_fitness;
#     for (int i = 1; i < population_size; i++) {
#         cumulative_prob[i] = cumulative_prob[i - 1] + population[i].fitness / total_fitness;
#     }
#
#     double r = (double)rand() / RAND_MAX;
#     for (int i = 0; i < population_size; i++) {
#         if (r <= cumulative_prob[i]) {
#             return i;
#         }
#     }
#     return population_size - 1;
# }
#
# void three_point_crossover(int parent1[], int parent2[], int offspring1[], int offspring2[], int length) {
#     int swap_start = length - 3; // Start of the last 3 features
#
#     for (int i = 0; i < length; i++) {
#         if (i < swap_start) {
#             offspring1[i] = parent1[i];
#             offspring2[i] = parent2[i];
#         } else {
#             offspring1[i] = parent2[i];
#             offspring2[i] = parent1[i];
#         }
#     }
# }
#
# void mutate(int chromosome[], int length, double mutation_rate) {
#     for (int i = 0; i < length; i++) {
#         double r = (double)rand() / RAND_MAX;
#         if (r < mutation_rate) {
#             chromosome[i] = 1 - chromosome[i]; // Flip bit
#         }
#     }
# }
# Out:
# Overwriting main.c

# %%
# !gcc -o main main.c

import time

t = time.time()
# !./main
# Out:
# Chromosome 1: [1 0 0 1 0 0 0]
# Selected Features: [0 3]
# Dataset Shape: (2200, 7)
# Accuracy: 0.3878787878787879
# Chromosome 2: [1 1 1 0 0 1 1]
# Selected Features: [0 1 2 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9636363636363636
# Chromosome 3: [1 1 1 1 0 0 1]
# Selected Features: [0 1 2 3 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.956060606060606
# Chromosome 4: [1 1 1 1 0 1 1]
# Selected Features: [0 1 2 3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9787878787878788
# Chromosome 5: [0 0 0 1 0 0 0]
# Selected Features: [3]
# Dataset Shape: (2200, 7)
# Accuracy: 0.16515151515151516
# Chromosome 6: [0 0 1 1 1 0 1]
# Selected Features: [2 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9742424242424242
# Chromosome 7: [0 1 0 1 0 1 0]
# Selected Features: [1 3 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.6848484848484848
# Chromosome 8: [1 0 0 0 1 1 1]
# Selected Features: [0 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9287878787878788
# Chromosome 9: [1 0 1 0 0 1 1]
# Selected Features: [0 2 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9257575757575758
# Chromosome 10: [0 1 0 0 1 1 0]
# Selected Features: [1 4 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.7454545454545455
# Chromosome 11: [1 1 1 1 0 0 0]
# Selected Features: [0 1 2 3]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8257575757575758
# Chromosome 12: [1 1 1 0 1 1 0]
# Selected Features: [0 1 2 4 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9409090909090909
# Chromosome 13: [1 0 1 0 0 0 0]
# Selected Features: [0 2]
# Dataset Shape: (2200, 7)
# Accuracy: 0.5409090909090909
# Chromosome 14: [0 1 0 0 0 0 0]
# Selected Features: [1]
# Dataset Shape: (2200, 7)
# Accuracy: 0.19545454545454546
# Chromosome 15: [0 1 0 1 0 0 0]
# Selected Features: [1 3]
# Dataset Shape: (2200, 7)
# Accuracy: 0.509090909090909
# Chromosome 16: [0 0 0 1 1 1 1]
# Selected Features: [3 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9454545454545454
# Chromosome 17: [1 0 1 0 0 1 0]
# Selected Features: [0 2 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.696969696969697
# Chromosome 18: [0 1 1 0 1 1 0]
# Selected Features: [1 2 4 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8848484848484849
# Chromosome 19: [1 1 1 1 0 1 0]
# Selected Features: [0 1 2 3 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9166666666666666
# Chromosome 20: [0 1 0 0 1 1 0]
# Selected Features: [1 4 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.7454545454545455
# Chromosome 21: [1 0 1 0 1 1 0]
# Selected Features: [0 2 4 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9090909090909091
# Chromosome 22: [1 0 0 0 1 1 0]
# Selected Features: [0 4 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.7333333333333333
# Chromosome 23: [0 0 1 0 1 0 1]
# Selected Features: [2 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9454545454545454
# Chromosome 24: [1 1 0 1 1 0 0]
# Selected Features: [0 1 3 4]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9045454545454545
# Chromosome 25: [0 1 0 1 0 1 1]
# Selected Features: [1 3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9090909090909091
# Chromosome 26: [1 0 1 0 0 0 0]
# Selected Features: [0 2]
# Dataset Shape: (2200, 7)
# Accuracy: 0.5409090909090909
# Chromosome 27: [0 1 1 0 0 0 0]
# Selected Features: [1 2]
# Dataset Shape: (2200, 7)
# Accuracy: 0.5378787878787878
# Chromosome 29: [0 0 0 1 0 0 0]
# Selected Features: [3]
# Dataset Shape: (2200, 7)
# Accuracy: 0.16515151515151516
# Chromosome 30: [0 0 0 1 0 1 1]
# Selected Features: [3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.75
# Chromosome 31: [1 1 0 1 1 1 1]
# Selected Features: [0 1 3 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9848484848484849
# Chromosome 32: [1 1 0 0 1 0 1]
# Selected Features: [0 1 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9681818181818181
# Chromosome 33: [0 0 0 1 0 0 0]
# Selected Features: [3]
# Dataset Shape: (2200, 7)
# Accuracy: 0.16515151515151516
# Chromosome 34: [0 1 0 0 1 0 1]
# Selected Features: [1 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9454545454545454
# Chromosome 35: [1 0 1 0 1 1 1]
# Selected Features: [0 2 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9833333333333333
# Chromosome 36: [0 0 1 1 1 1 0]
# Selected Features: [2 3 4 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8772727272727273
# Chromosome 37: [0 1 1 0 1 1 1]
# Selected Features: [1 2 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9787878787878788
# Chromosome 38: [1 0 1 0 1 0 0]
# Selected Features: [0 2 4]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8666666666666667
# Chromosome 39: [0 0 0 1 0 1 0]
# Selected Features: [3 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.37727272727272726
# Chromosome 40: [0 0 1 0 0 0 0]
# Selected Features: [2]
# Dataset Shape: (2200, 7)
# Accuracy: 0.2787878787878788
# Chromosome 41: [1 1 0 1 0 1 1]
# Selected Features: [0 1 3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9515151515151515
# Chromosome 42: [1 1 1 1 1 0 1]
# Selected Features: [0 1 2 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9924242424242424
# Chromosome 43: [0 0 1 0 1 1 1]
# Selected Features: [2 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9727272727272728
# Chromosome 44: [1 0 1 1 0 1 0]
# Selected Features: [0 2 3 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8424242424242424
# Chromosome 45: [0 1 0 1 1 0 0]
# Selected Features: [1 3 4]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8075757575757576
# Chromosome 46: [1 1 0 1 0 1 0]
# Selected Features: [0 1 3 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8378787878787879
# Chromosome 47: [1 1 1 1 0 0 1]
# Selected Features: [0 1 2 3 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.956060606060606
# Chromosome 48: [1 0 1 0 0 0 0]
# Selected Features: [0 2]
# Dataset Shape: (2200, 7)
# Accuracy: 0.5409090909090909
# Chromosome 49: [1 1 0 1 1 0 1]
# Selected Features: [0 1 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9742424242424242
# Chromosome 50: [0 0 1 1 1 1 0]
# Selected Features: [2 3 4 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8772727272727273
#
# === Generation 0 ===
# Chromosome 3: [1 1 0 1 1 1 0]
# Selected Features: [0 1 3 4 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9363636363636364
# Chromosome 2: [1 0 1 0 1 1 1]
# Selected Features: [0 2 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9833333333333333
# Chromosome 5: [1 1 0 1 1 1 1]
# Selected Features: [0 1 3 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9848484848484849
# Chromosome 4: [0 1 1 0 0 1 1]
# Selected Features: [1 2 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9090909090909091
# Chromosome 7: [0 1 0 1 0 1 0]
# Selected Features: [1 3 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.6848484848484848
# Chromosome 6: [0 1 1 0 0 1 1]
# Selected Features: [1 2 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9090909090909091
# Chromosome 9: [0 0 0 1 0 1 1]
# Selected Features: [3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.75
# Chromosome 8: [1 1 0 1 0 1 1]
# Selected Features: [0 1 3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9515151515151515
# Chromosome 11: [1 1 1 1 1 1 1]
# Selected Features: [0 1 2 3 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9893939393939394
# Chromosome 10: [0 0 1 0 1 0 1]
# Selected Features: [2 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9454545454545454
# Chromosome 13: [1 1 1 1 0 1 0]
# Selected Features: [0 1 2 3 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9166666666666666
# Chromosome 12: [1 0 1 0 0 1 0]
# Selected Features: [0 2 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.696969696969697
# Chromosome 15: [1 0 1 1 1 0 1]
# Selected Features: [0 2 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9787878787878788
# Chromosome 14: [0 0 1 0 0 1 0]
# Selected Features: [2 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.4681818181818182
# Chromosome 17: [1 1 1 1 1 0 1]
# Selected Features: [0 1 2 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9924242424242424
# Chromosome 16: [1 1 1 1 0 0 1]
# Selected Features: [0 1 2 3 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.956060606060606
# Chromosome 19: [0 1 0 0 1 0 1]
# Selected Features: [1 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9454545454545454
# Chromosome 18: [0 1 0 1 1 1 0]
# Selected Features: [1 3 4 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8621212121212121
# Chromosome 21: [0 1 0 1 0 1 0]
# Selected Features: [1 3 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.6848484848484848
# Chromosome 20: [1 1 1 1 0 1 1]
# Selected Features: [0 1 2 3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9787878787878788
# Chromosome 23: [0 1 1 0 1 0 0]
# Selected Features: [1 2 4]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8696969696969697
# Chromosome 22: [0 1 0 0 1 1 1]
# Selected Features: [1 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.956060606060606
# Chromosome 25: [0 0 1 0 0 0 0]
# Selected Features: [2]
# Dataset Shape: (2200, 7)
# Accuracy: 0.2787878787878788
# Chromosome 24: [1 0 1 0 1 0 1]
# Selected Features: [0 2 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9727272727272728
# Chromosome 27: [0 1 1 0 0 1 0]
# Selected Features: [1 2 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.6909090909090909
# Chromosome 26: [1 0 1 1 1 1 0]
# Selected Features: [0 2 3 4 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9363636363636364
# Chromosome 29: [0 1 0 1 0 0 0]
# Selected Features: [1 3]
# Dataset Shape: (2200, 7)
# Accuracy: 0.509090909090909
# Chromosome 28: [1 0 0 1 0 0 0]
# Selected Features: [0 3]
# Dataset Shape: (2200, 7)
# Accuracy: 0.3878787878787879
# Chromosome 31: [1 1 1 1 1 0 1]
# Selected Features: [0 1 2 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9924242424242424
# Chromosome 30: [1 1 0 1 0 0 1]
# Selected Features: [0 1 3 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9272727272727272
# Chromosome 33: [1 1 1 1 0 1 1]
# Selected Features: [0 1 2 3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9787878787878788
# Chromosome 32: [1 1 0 1 0 0 0]
# Selected Features: [0 1 3]
# Dataset Shape: (2200, 7)
# Accuracy: 0.7090909090909091
# Chromosome 35: [0 0 1 1 1 0 1]
# Selected Features: [2 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9742424242424242
# Chromosome 34: [0 0 1 1 1 1 0]
# Selected Features: [2 3 4 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8772727272727273
# Chromosome 37: [1 1 1 1 0 1 1]
# Selected Features: [0 1 2 3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9787878787878788
# Chromosome 36: [1 1 1 0 0 1 1]
# Selected Features: [0 1 2 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9636363636363636
# Chromosome 39: [0 1 0 1 0 1 0]
# Selected Features: [1 3 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.6848484848484848
# Chromosome 38: [1 1 0 1 1 0 0]
# Selected Features: [0 1 3 4]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9045454545454545
# Chromosome 41: [1 0 1 0 1 1 0]
# Selected Features: [0 2 4 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9090909090909091
# Chromosome 40: [1 0 0 0 1 1 0]
# Selected Features: [0 4 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.7333333333333333
# Chromosome 43: [1 0 0 0 1 1 1]
# Selected Features: [0 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9287878787878788
# Chromosome 42: [1 0 1 0 1 1 1]
# Selected Features: [0 2 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9833333333333333
# Chromosome 45: [1 0 1 0 1 0 1]
# Selected Features: [0 2 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9727272727272728
# Chromosome 44: [1 1 0 0 1 0 0]
# Selected Features: [0 1 4]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8424242424242424
# Chromosome 47: [1 1 0 0 1 0 1]
# Selected Features: [0 1 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9681818181818181
# Chromosome 46: [1 1 0 1 1 0 1]
# Selected Features: [0 1 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9742424242424242
# Chromosome 49: [0 1 0 1 0 1 1]
# Selected Features: [1 3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9090909090909091
# Chromosome 48: [0 0 0 1 1 1 1]
# Selected Features: [3 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9454545454545454
# Chromosome 50: [1 0 1 0 1 0 1]
# Selected Features: [0 2 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9727272727272728
# Chromosome 42: [1 1 1 1 1 0 1] Accuracy: 0.9924
# Chromosome 2: [1 0 1 0 1 1 1] Accuracy: 0.9833
# Chromosome 3: [1 1 0 1 1 1 0] Accuracy: 0.9364
# Chromosome 4: [0 1 1 0 0 1 1] Accuracy: 0.9091
# Chromosome 5: [1 1 0 1 1 1 1] Accuracy: 0.9848
# Chromosome 6: [0 1 1 0 0 1 1] Accuracy: 0.9091
# Chromosome 7: [0 1 0 1 0 1 0] Accuracy: 0.6848
# Chromosome 8: [1 1 0 1 0 1 1] Accuracy: 0.9515
# Chromosome 9: [0 0 0 1 0 1 1] Accuracy: 0.7500
# Chromosome 10: [0 0 1 0 1 0 1] Accuracy: 0.9455
# Chromosome 11: [1 1 1 1 1 1 1] Accuracy: 0.9894
# Chromosome 12: [1 0 1 0 0 1 0] Accuracy: 0.6970
# Chromosome 13: [1 1 1 1 0 1 0] Accuracy: 0.9167
# Chromosome 14: [0 0 1 0 0 1 0] Accuracy: 0.4682
# Chromosome 15: [1 0 1 1 1 0 1] Accuracy: 0.9788
# Chromosome 16: [1 1 1 1 0 0 1] Accuracy: 0.9561
# Chromosome 17: [1 1 1 1 1 0 1] Accuracy: 0.9924
# Chromosome 18: [0 1 0 1 1 1 0] Accuracy: 0.8621
# Chromosome 19: [0 1 0 0 1 0 1] Accuracy: 0.9455
# Chromosome 20: [1 1 1 1 0 1 1] Accuracy: 0.9788
# Chromosome 21: [0 1 0 1 0 1 0] Accuracy: 0.6848
# Chromosome 22: [0 1 0 0 1 1 1] Accuracy: 0.9561
# Chromosome 23: [0 1 1 0 1 0 0] Accuracy: 0.8697
# Chromosome 24: [1 0 1 0 1 0 1] Accuracy: 0.9727
# Chromosome 25: [0 0 1 0 0 0 0] Accuracy: 0.2788
# Chromosome 26: [1 0 1 1 1 1 0] Accuracy: 0.9364
# Chromosome 27: [0 1 1 0 0 1 0] Accuracy: 0.6909
# Chromosome 28: [1 0 0 1 0 0 0] Accuracy: 0.3879
# Chromosome 29: [0 1 0 1 0 0 0] Accuracy: 0.5091
# Chromosome 30: [1 1 0 1 0 0 1] Accuracy: 0.9273
# Chromosome 31: [1 1 1 1 1 0 1] Accuracy: 0.9924
# Chromosome 32: [1 1 0 1 0 0 0] Accuracy: 0.7091
# Chromosome 33: [1 1 1 1 0 1 1] Accuracy: 0.9788
# Chromosome 34: [0 0 1 1 1 1 0] Accuracy: 0.8773
# Chromosome 35: [0 0 1 1 1 0 1] Accuracy: 0.9742
# Chromosome 36: [1 1 1 0 0 1 1] Accuracy: 0.9636
# Chromosome 37: [1 1 1 1 0 1 1] Accuracy: 0.9788
# Chromosome 38: [1 1 0 1 1 0 0] Accuracy: 0.9045
# Chromosome 39: [0 1 0 1 0 1 0] Accuracy: 0.6848
# Chromosome 40: [1 0 0 0 1 1 0] Accuracy: 0.7333
# Chromosome 41: [1 0 1 0 1 1 0] Accuracy: 0.9091
# Chromosome 42: [1 0 1 0 1 1 1] Accuracy: 0.9833
# Chromosome 43: [1 0 0 0 1 1 1] Accuracy: 0.9288
# Chromosome 44: [1 1 0 0 1 0 0] Accuracy: 0.8424
# Chromosome 45: [1 0 1 0 1 0 1] Accuracy: 0.9727
# Chromosome 46: [1 1 0 1 1 0 1] Accuracy: 0.9742
# Chromosome 47: [1 1 0 0 1 0 1] Accuracy: 0.9682
# Chromosome 48: [0 0 0 1 1 1 1] Accuracy: 0.9455
# Chromosome 49: [0 1 0 1 0 1 1] Accuracy: 0.9091
# Chromosome 50: [1 0 1 0 1 0 1] Accuracy: 0.9727
# Best Fitness in Generation 0: 0.9924 (ID: 42)
#
# === Generation 1 ===
# Chromosome 3: [1 1 1 1 1 1 1]
# Selected Features: [0 1 2 3 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9893939393939394
# Chromosome 2: [0 1 0 0 0 0 1]
# Selected Features: [1 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.6439393939393939
# Chromosome 5: [1 1 0 1 1 0 1]
# Selected Features: [0 1 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9742424242424242
# Chromosome 4: [1 0 1 0 1 0 0]
# Selected Features: [0 2 4]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8666666666666667
# Chromosome 7: [0 0 1 1 1 0 1]
# Selected Features: [2 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9742424242424242
# Chromosome 6: [1 0 1 0 1 0 1]
# Selected Features: [0 2 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9727272727272728
# Chromosome 9: [0 1 0 1 1 1 1]
# Selected Features: [1 3 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9818181818181818
# Chromosome 8: [0 1 0 0 0 1 0]
# Selected Features: [1 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.37424242424242427
# Chromosome 11: [1 1 1 1 0 1 1]
# Selected Features: [0 1 2 3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9787878787878788
# Chromosome 10: [0 1 1 0 1 0 1]
# Selected Features: [1 2 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9681818181818181
# Chromosome 13: [0 1 0 1 0 0 1]
# Selected Features: [1 3 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8545454545454545
# Chromosome 12: [1 1 0 1 0 0 0]
# Selected Features: [0 1 3]
# Dataset Shape: (2200, 7)
# Accuracy: 0.7090909090909091
# Chromosome 15: [1 1 1 1 1 1 1]
# Selected Features: [0 1 2 3 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9893939393939394
# Chromosome 14: [1 1 0 1 0 1 0]
# Selected Features: [0 1 3 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8378787878787879
# Chromosome 17: [1 1 1 0 0 1 0]
# Selected Features: [0 1 2 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.796969696969697
# Chromosome 16: [0 1 0 1 1 0 1]
# Selected Features: [1 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9803030303030303
# Chromosome 19: [0 1 0 1 0 1 1]
# Selected Features: [1 3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9090909090909091
# Chromosome 18: [1 1 1 1 0 0 0]
# Selected Features: [0 1 2 3]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8257575757575758
# Chromosome 21: [0 0 0 1 0 1 0]
# Selected Features: [3 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.37727272727272726
# Chromosome 20: [0 1 1 0 1 1 1]
# Selected Features: [1 2 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9787878787878788
# Chromosome 23: [0 0 1 0 0 1 1]
# Selected Features: [2 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8348484848484848
# Chromosome 22: [0 1 1 0 1 0 1]
# Selected Features: [1 2 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9681818181818181
# Chromosome 25: [1 1 1 0 1 0 1]
# Selected Features: [0 1 2 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9878787878787879
# Chromosome 24: [0 1 0 0 0 1 1]
# Selected Features: [1 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8106060606060606
# Chromosome 27: [1 1 1 1 0 0 0]
# Selected Features: [0 1 2 3]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8257575757575758
# Chromosome 26: [1 1 0 1 0 0 1]
# Selected Features: [0 1 3 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9272727272727272
# Chromosome 29: [1 1 1 1 1 1 1]
# Selected Features: [0 1 2 3 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9893939393939394
# Chromosome 28: [1 0 1 0 0 1 1]
# Selected Features: [0 2 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9257575757575758
# Chromosome 31: [1 1 1 1 0 1 1]
# Selected Features: [0 1 2 3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9787878787878788
# Chromosome 30: [0 0 0 1 0 1 0]
# Selected Features: [3 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.37727272727272726
# Chromosome 33: [1 1 1 1 1 0 1]
# Selected Features: [0 1 2 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9924242424242424
# Chromosome 32: [0 0 1 1 0 0 1]
# Selected Features: [2 3 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8333333333333334
# Chromosome 35: [1 1 1 1 1 0 1]
# Selected Features: [0 1 2 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9924242424242424
# Chromosome 34: [1 0 1 0 1 0 1]
# Selected Features: [0 2 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9727272727272728
# Chromosome 37: [1 1 1 1 0 1 1]
# Selected Features: [0 1 2 3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9787878787878788
# Chromosome 36: [1 1 1 1 0 1 1]
# Selected Features: [0 1 2 3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9787878787878788
# Chromosome 39: [0 1 1 0 0 1 1]
# Selected Features: [1 2 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9090909090909091
# Chromosome 38: [1 1 1 1 0 1 1]
# Selected Features: [0 1 2 3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9787878787878788
# Chromosome 41: [1 1 0 1 0 0 1]
# Selected Features: [0 1 3 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9272727272727272
# Chromosome 40: [1 1 1 1 0 1 1]
# Selected Features: [0 1 2 3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9787878787878788
# Chromosome 43: [1 0 1 0 0 1 1]
# Selected Features: [0 2 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9257575757575758
# Chromosome 42: [0 1 1 0 1 0 1]
# Selected Features: [1 2 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9681818181818181
# Chromosome 45: [1 1 0 1 0 1 0]
# Selected Features: [0 1 3 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8378787878787879
# Chromosome 44: [1 1 1 1 1 0 0]
# Selected Features: [0 1 2 3 4]
# Dataset Shape: (2200, 7)
# Accuracy: 0.956060606060606
# Chromosome 47: [1 1 0 1 1 0 1]
# Selected Features: [0 1 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9742424242424242
# Chromosome 46: [1 1 1 1 1 1 1]
# Selected Features: [0 1 2 3 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9893939393939394
# Chromosome 49: [1 0 1 0 1 0 0]
# Selected Features: [0 2 4]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8666666666666667
# Chromosome 48: [1 1 0 0 1 0 1]
# Selected Features: [0 1 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9681818181818181
# Chromosome 50: [0 1 1 0 1 0 1]
# Selected Features: [1 2 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9681818181818181
# Chromosome 42: [1 1 1 1 1 0 1] Accuracy: 0.9924
# Chromosome 2: [0 1 0 0 0 0 1] Accuracy: 0.6439
# Chromosome 3: [1 1 1 1 1 1 1] Accuracy: 0.9894
# Chromosome 4: [1 0 1 0 1 0 0] Accuracy: 0.8667
# Chromosome 5: [1 1 0 1 1 0 1] Accuracy: 0.9742
# Chromosome 6: [1 0 1 0 1 0 1] Accuracy: 0.9727
# Chromosome 7: [0 0 1 1 1 0 1] Accuracy: 0.9742
# Chromosome 8: [0 1 0 0 0 1 0] Accuracy: 0.3742
# Chromosome 9: [0 1 0 1 1 1 1] Accuracy: 0.9818
# Chromosome 10: [0 1 1 0 1 0 1] Accuracy: 0.9682
# Chromosome 11: [1 1 1 1 0 1 1] Accuracy: 0.9788
# Chromosome 12: [1 1 0 1 0 0 0] Accuracy: 0.7091
# Chromosome 13: [0 1 0 1 0 0 1] Accuracy: 0.8545
# Chromosome 14: [1 1 0 1 0 1 0] Accuracy: 0.8379
# Chromosome 15: [1 1 1 1 1 1 1] Accuracy: 0.9894
# Chromosome 16: [0 1 0 1 1 0 1] Accuracy: 0.9803
# Chromosome 17: [1 1 1 0 0 1 0] Accuracy: 0.7970
# Chromosome 18: [1 1 1 1 0 0 0] Accuracy: 0.8258
# Chromosome 19: [0 1 0 1 0 1 1] Accuracy: 0.9091
# Chromosome 20: [0 1 1 0 1 1 1] Accuracy: 0.9788
# Chromosome 21: [0 0 0 1 0 1 0] Accuracy: 0.3773
# Chromosome 22: [0 1 1 0 1 0 1] Accuracy: 0.9682
# Chromosome 23: [0 0 1 0 0 1 1] Accuracy: 0.8348
# Chromosome 24: [0 1 0 0 0 1 1] Accuracy: 0.8106
# Chromosome 25: [1 1 1 0 1 0 1] Accuracy: 0.9879
# Chromosome 26: [1 1 0 1 0 0 1] Accuracy: 0.9273
# Chromosome 27: [1 1 1 1 0 0 0] Accuracy: 0.8258
# Chromosome 28: [1 0 1 0 0 1 1] Accuracy: 0.9258
# Chromosome 29: [1 1 1 1 1 1 1] Accuracy: 0.9894
# Chromosome 30: [0 0 0 1 0 1 0] Accuracy: 0.3773
# Chromosome 31: [1 1 1 1 0 1 1] Accuracy: 0.9788
# Chromosome 32: [0 0 1 1 0 0 1] Accuracy: 0.8333
# Chromosome 33: [1 1 1 1 1 0 1] Accuracy: 0.9924
# Chromosome 34: [1 0 1 0 1 0 1] Accuracy: 0.9727
# Chromosome 35: [1 1 1 1 1 0 1] Accuracy: 0.9924
# Chromosome 36: [1 1 1 1 0 1 1] Accuracy: 0.9788
# Chromosome 37: [1 1 1 1 0 1 1] Accuracy: 0.9788
# Chromosome 38: [1 1 1 1 0 1 1] Accuracy: 0.9788
# Chromosome 39: [0 1 1 0 0 1 1] Accuracy: 0.9091
# Chromosome 40: [1 1 1 1 0 1 1] Accuracy: 0.9788
# Chromosome 41: [1 1 0 1 0 0 1] Accuracy: 0.9273
# Chromosome 42: [0 1 1 0 1 0 1] Accuracy: 0.9682
# Chromosome 43: [1 0 1 0 0 1 1] Accuracy: 0.9258
# Chromosome 44: [1 1 1 1 1 0 0] Accuracy: 0.9561
# Chromosome 45: [1 1 0 1 0 1 0] Accuracy: 0.8379
# Chromosome 46: [1 1 1 1 1 1 1] Accuracy: 0.9894
# Chromosome 47: [1 1 0 1 1 0 1] Accuracy: 0.9742
# Chromosome 48: [1 1 0 0 1 0 1] Accuracy: 0.9682
# Chromosome 49: [1 0 1 0 1 0 0] Accuracy: 0.8667
# Chromosome 50: [0 1 1 0 1 0 1] Accuracy: 0.9682
# Best Fitness in Generation 1: 0.9924 (ID: 42)
# No improvement in generation 1. Stagnation count: 1
#
# === Generation 2 ===
# Chromosome 3: [1 0 1 0 1 0 1]
# Selected Features: [0 2 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9727272727272728
# Chromosome 2: [1 1 0 1 1 0 1]
# Selected Features: [0 1 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9742424242424242
# Chromosome 5: [0 1 0 1 0 1 1]
# Selected Features: [1 3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9090909090909091
# Chromosome 4: [0 0 1 0 1 0 1]
# Selected Features: [2 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9454545454545454
# Chromosome 7: [0 1 1 0 1 1 1]
# Selected Features: [1 2 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9787878787878788
# Chromosome 6: [1 1 1 1 1 0 1]
# Selected Features: [0 1 2 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9924242424242424
# Chromosome 9: [0 0 1 0 0 0 0]
# Selected Features: [2]
# Dataset Shape: (2200, 7)
# Accuracy: 0.2787878787878788
# Chromosome 8: [0 0 0 1 1 1 1]
# Selected Features: [3 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9454545454545454
# Chromosome 11: [1 0 1 0 0 1 0]
# Selected Features: [0 2 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.696969696969697
# Chromosome 10: [1 1 0 1 1 0 0]
# Selected Features: [0 1 3 4]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9045454545454545
# Chromosome 13: [1 0 1 0 0 1 1]
# Selected Features: [0 2 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9257575757575758
# Chromosome 12: [1 1 1 1 1 0 0]
# Selected Features: [0 1 2 3 4]
# Dataset Shape: (2200, 7)
# Accuracy: 0.956060606060606
# Chromosome 15: [0 1 1 0 1 0 1]
# Selected Features: [1 2 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9681818181818181
# Chromosome 14: [1 0 1 0 1 0 1]
# Selected Features: [0 2 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9727272727272728
# Chromosome 17: [1 1 1 1 1 0 1]
# Selected Features: [0 1 2 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9924242424242424
# Chromosome 16: [1 1 1 1 0 1 1]
# Selected Features: [0 1 2 3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9787878787878788
# Chromosome 19: [1 1 1 1 1 1 1]
# Selected Features: [0 1 2 3 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9893939393939394
# Chromosome 18: [0 1 0 1 1 1 1]
# Selected Features: [1 3 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9818181818181818
# Chromosome 21: [0 1 0 1 0 1 1]
# Selected Features: [1 3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9090909090909091
# Chromosome 20: [0 1 0 1 0 0 1]
# Selected Features: [1 3 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8545454545454545
# Chromosome 23: [1 1 1 1 0 0 1]
# Selected Features: [0 1 2 3 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.956060606060606
# Chromosome 22: [0 0 1 1 0 1 1]
# Selected Features: [2 3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8863636363636364
# Chromosome 25: [1 1 1 1 1 0 1]
# Selected Features: [0 1 2 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9924242424242424
# Chromosome 24: [1 0 1 0 1 1 1]
# Selected Features: [0 2 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9833333333333333
# Chromosome 27: [1 1 1 1 1 0 1]
# Selected Features: [0 1 2 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9924242424242424
# Chromosome 26: [0 1 1 0 0 1 1]
# Selected Features: [1 2 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9090909090909091
# Chromosome 29: [0 1 0 1 0 1 1]
# Selected Features: [1 3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9090909090909091
# Chromosome 28: [1 0 1 0 1 0 1]
# Selected Features: [0 2 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9727272727272728
# Chromosome 31: [1 1 0 1 0 1 1]
# Selected Features: [0 1 3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9515151515151515
# Chromosome 30: [1 0 1 0 1 0 1]
# Selected Features: [0 2 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9727272727272728
# Chromosome 33: [1 0 1 0 0 1 0]
# Selected Features: [0 2 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.696969696969697
# Chromosome 32: [1 1 1 1 1 0 1]
# Selected Features: [0 1 2 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9924242424242424
# Chromosome 35: [1 0 1 0 1 0 1]
# Selected Features: [0 2 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9727272727272728
# Chromosome 34: [1 1 1 1 0 1 1]
# Selected Features: [0 1 2 3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9787878787878788
# Chromosome 37: [1 0 1 0 0 1 0]
# Selected Features: [0 2 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.696969696969697
# Chromosome 36: [0 1 0 0 1 0 1]
# Selected Features: [1 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9454545454545454
# Chromosome 39: [0 0 0 1 0 0 0]
# Selected Features: [3]
# Dataset Shape: (2200, 7)
# Accuracy: 0.16515151515151516
# Chromosome 38: [1 1 0 1 0 1 0]
# Selected Features: [0 1 3 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8378787878787879
# Chromosome 41: [1 1 1 1 1 0 1]
# Selected Features: [0 1 2 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9924242424242424
# Chromosome 40: [1 1 0 0 1 0 1]
# Selected Features: [0 1 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9681818181818181
# Chromosome 43: [1 1 0 1 0 0 0]
# Selected Features: [0 1 3]
# Dataset Shape: (2200, 7)
# Accuracy: 0.7090909090909091
# Chromosome 42: [1 1 1 1 1 0 1]
# Selected Features: [0 1 2 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9924242424242424
# Chromosome 45: [0 1 0 0 1 1 1]
# Selected Features: [1 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.956060606060606
# Chromosome 44: [1 1 1 1 0 1 1]
# Selected Features: [0 1 2 3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9787878787878788
# Chromosome 47: [0 1 0 1 1 0 1]
# Selected Features: [1 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9803030303030303
# Chromosome 46: [1 1 0 1 1 1 1]
# Selected Features: [0 1 3 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9848484848484849
# Chromosome 49: [0 1 0 1 0 1 1]
# Selected Features: [1 3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9090909090909091
# Chromosome 48: [1 0 1 0 1 0 1]
# Selected Features: [0 2 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9727272727272728
# Chromosome 50: [0 1 1 0 1 0 1]
# Selected Features: [1 2 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9681818181818181
# Chromosome 42: [1 1 1 1 1 0 1] Accuracy: 0.9924
# Chromosome 2: [1 1 0 1 1 0 1] Accuracy: 0.9742
# Chromosome 3: [1 0 1 0 1 0 1] Accuracy: 0.9727
# Chromosome 4: [0 0 1 0 1 0 1] Accuracy: 0.9455
# Chromosome 5: [0 1 0 1 0 1 1] Accuracy: 0.9091
# Chromosome 6: [1 1 1 1 1 0 1] Accuracy: 0.9924
# Chromosome 7: [0 1 1 0 1 1 1] Accuracy: 0.9788
# Chromosome 8: [0 0 0 1 1 1 1] Accuracy: 0.9455
# Chromosome 9: [0 0 1 0 0 0 0] Accuracy: 0.2788
# Chromosome 10: [1 1 0 1 1 0 0] Accuracy: 0.9045
# Chromosome 11: [1 0 1 0 0 1 0] Accuracy: 0.6970
# Chromosome 12: [1 1 1 1 1 0 0] Accuracy: 0.9561
# Chromosome 13: [1 0 1 0 0 1 1] Accuracy: 0.9258
# Chromosome 14: [1 0 1 0 1 0 1] Accuracy: 0.9727
# Chromosome 15: [0 1 1 0 1 0 1] Accuracy: 0.9682
# Chromosome 16: [1 1 1 1 0 1 1] Accuracy: 0.9788
# Chromosome 17: [1 1 1 1 1 0 1] Accuracy: 0.9924
# Chromosome 18: [0 1 0 1 1 1 1] Accuracy: 0.9818
# Chromosome 19: [1 1 1 1 1 1 1] Accuracy: 0.9894
# Chromosome 20: [0 1 0 1 0 0 1] Accuracy: 0.8545
# Chromosome 21: [0 1 0 1 0 1 1] Accuracy: 0.9091
# Chromosome 22: [0 0 1 1 0 1 1] Accuracy: 0.8864
# Chromosome 23: [1 1 1 1 0 0 1] Accuracy: 0.9561
# Chromosome 24: [1 0 1 0 1 1 1] Accuracy: 0.9833
# Chromosome 25: [1 1 1 1 1 0 1] Accuracy: 0.9924
# Chromosome 26: [0 1 1 0 0 1 1] Accuracy: 0.9091
# Chromosome 27: [1 1 1 1 1 0 1] Accuracy: 0.9924
# Chromosome 28: [1 0 1 0 1 0 1] Accuracy: 0.9727
# Chromosome 29: [0 1 0 1 0 1 1] Accuracy: 0.9091
# Chromosome 30: [1 0 1 0 1 0 1] Accuracy: 0.9727
# Chromosome 31: [1 1 0 1 0 1 1] Accuracy: 0.9515
# Chromosome 32: [1 1 1 1 1 0 1] Accuracy: 0.9924
# Chromosome 33: [1 0 1 0 0 1 0] Accuracy: 0.6970
# Chromosome 34: [1 1 1 1 0 1 1] Accuracy: 0.9788
# Chromosome 35: [1 0 1 0 1 0 1] Accuracy: 0.9727
# Chromosome 36: [0 1 0 0 1 0 1] Accuracy: 0.9455
# Chromosome 37: [1 0 1 0 0 1 0] Accuracy: 0.6970
# Chromosome 38: [1 1 0 1 0 1 0] Accuracy: 0.8379
# Chromosome 39: [0 0 0 1 0 0 0] Accuracy: 0.1652
# Chromosome 40: [1 1 0 0 1 0 1] Accuracy: 0.9682
# Chromosome 41: [1 1 1 1 1 0 1] Accuracy: 0.9924
# Chromosome 42: [1 1 1 1 1 0 1] Accuracy: 0.9924
# Chromosome 43: [1 1 0 1 0 0 0] Accuracy: 0.7091
# Chromosome 44: [1 1 1 1 0 1 1] Accuracy: 0.9788
# Chromosome 45: [0 1 0 0 1 1 1] Accuracy: 0.9561
# Chromosome 46: [1 1 0 1 1 1 1] Accuracy: 0.9848
# Chromosome 47: [0 1 0 1 1 0 1] Accuracy: 0.9803
# Chromosome 48: [1 0 1 0 1 0 1] Accuracy: 0.9727
# Chromosome 49: [0 1 0 1 0 1 1] Accuracy: 0.9091
# Chromosome 50: [0 1 1 0 1 0 1] Accuracy: 0.9682
# Best Fitness in Generation 2: 0.9924 (ID: 42)
# No improvement in generation 2. Stagnation count: 2
#
# === Generation 3 ===
# Chromosome 3: [0 1 0 1 1 1 1]
# Selected Features: [1 3 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9818181818181818
# Chromosome 2: [0 1 1 0 0 1 1]
# Selected Features: [1 2 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9090909090909091
# Chromosome 5: [1 1 0 1 1 0 1]
# Selected Features: [0 1 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9742424242424242
# Chromosome 4: [1 1 0 0 1 0 0]
# Selected Features: [0 1 4]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8424242424242424
# Chromosome 7: [1 0 1 0 1 1 1]
# Selected Features: [0 2 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9833333333333333
# Chromosome 6: [1 1 1 1 1 0 1]
# Selected Features: [0 1 2 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9924242424242424
# Chromosome 9: [1 1 1 1 0 1 1]
# Selected Features: [0 1 2 3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9787878787878788
# Chromosome 8: [1 0 1 0 0 1 1]
# Selected Features: [0 2 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9257575757575758
# Chromosome 11: [1 0 1 0 1 1 1]
# Selected Features: [0 2 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9833333333333333
# Chromosome 10: [1 1 1 1 1 0 0]
# Selected Features: [0 1 2 3 4]
# Dataset Shape: (2200, 7)
# Accuracy: 0.956060606060606
# Chromosome 13: [0 1 0 1 1 0 1]
# Selected Features: [1 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9803030303030303
# Chromosome 12: [0 1 0 1 1 0 1]
# Selected Features: [1 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9803030303030303
# Chromosome 15: [1 1 0 1 1 0 1]
# Selected Features: [0 1 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9742424242424242
# Chromosome 14: [1 1 1 1 1 1 1]
# Selected Features: [0 1 2 3 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9893939393939394
# Chromosome 17: [1 0 1 0 0 0 1]
# Selected Features: [0 2 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8424242424242424
# Chromosome 16: [0 1 0 1 0 1 1]
# Selected Features: [1 3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9090909090909091
# Chromosome 19: [0 1 0 1 1 1 1]
# Selected Features: [1 3 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9818181818181818
# Chromosome 18: [0 1 1 0 0 1 1]
# Selected Features: [1 2 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9090909090909091
# Chromosome 21: [1 0 1 0 0 1 1]
# Selected Features: [0 2 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9257575757575758
# Chromosome 20: [0 1 1 0 1 0 1]
# Selected Features: [1 2 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9681818181818181
# Chromosome 23: [1 0 1 0 0 0 1]
# Selected Features: [0 2 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8424242424242424
# Chromosome 22: [0 1 0 1 1 0 1]
# Selected Features: [1 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9803030303030303
# Chromosome 25: [1 1 1 1 1 0 1]
# Selected Features: [0 1 2 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9924242424242424
# Chromosome 24: [1 1 1 1 1 0 0]
# Selected Features: [0 1 2 3 4]
# Dataset Shape: (2200, 7)
# Accuracy: 0.956060606060606
# Chromosome 27: [1 1 0 0 1 1 1]
# Selected Features: [0 1 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9621212121212122
# Chromosome 26: [0 1 0 0 1 0 1]
# Selected Features: [1 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9454545454545454
# Chromosome 29: [0 1 1 0 1 0 1]
# Selected Features: [1 2 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9681818181818181
# Chromosome 28: [1 1 1 1 1 0 1]
# Selected Features: [0 1 2 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9924242424242424
# Chromosome 31: [1 0 1 0 1 0 1]
# Selected Features: [0 2 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9727272727272728
# Chromosome 30: [1 1 1 1 0 1 1]
# Selected Features: [0 1 2 3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9787878787878788
# Chromosome 33: [1 0 1 0 0 1 1]
# Selected Features: [0 2 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9257575757575758
# Chromosome 32: [1 0 1 0 1 0 1]
# Selected Features: [0 2 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9727272727272728
# Chromosome 35: [1 1 0 1 1 1 1]
# Selected Features: [0 1 3 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9848484848484849
# Chromosome 34: [0 1 0 0 0 1 1]
# Selected Features: [1 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8106060606060606
# Chromosome 37: [0 1 0 1 1 0 1]
# Selected Features: [1 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9803030303030303
# Chromosome 36: [1 1 0 1 1 0 1]
# Selected Features: [0 1 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9742424242424242
# Chromosome 39: [1 1 1 1 0 1 1]
# Selected Features: [0 1 2 3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9787878787878788
# Chromosome 38: [0 1 0 1 1 0 1]
# Selected Features: [1 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9803030303030303
# Chromosome 41: [0 1 1 0 1 1 0]
# Selected Features: [1 2 4 5]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8848484848484849
# Chromosome 40: [0 1 0 1 1 1 1]
# Selected Features: [1 3 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9818181818181818
# Chromosome 43: [0 1 1 0 1 0 1]
# Selected Features: [1 2 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9681818181818181
# Chromosome 42: [1 0 1 0 1 0 1]
# Selected Features: [0 2 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9727272727272728
# Chromosome 45: [1 1 1 1 1 1 1]
# Selected Features: [0 1 2 3 4 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9893939393939394
# Chromosome 44: [0 1 0 0 0 1 1]
# Selected Features: [1 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.8106060606060606
# Chromosome 47: [1 0 1 0 1 0 1]
# Selected Features: [0 2 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9727272727272728
# Chromosome 46: [1 1 1 1 0 1 1]
# Selected Features: [0 1 2 3 5 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9787878787878788
# Chromosome 49: [1 1 1 1 1 0 0]
# Selected Features: [0 1 2 3 4]
# Dataset Shape: (2200, 7)
# Accuracy: 0.956060606060606
# Chromosome 48: [1 1 1 1 1 0 1]
# Selected Features: [0 1 2 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9924242424242424
# Chromosome 50: [0 1 0 1 1 0 1]
# Selected Features: [1 3 4 6]
# Dataset Shape: (2200, 7)
# Accuracy: 0.9803030303030303
# Chromosome 42: [1 1 1 1 1 0 1] Accuracy: 0.9924
# Chromosome 2: [0 1 1 0 0 1 1] Accuracy: 0.9091
# Chromosome 3: [0 1 0 1 1 1 1] Accuracy: 0.9818
# Chromosome 4: [1 1 0 0 1 0 0] Accuracy: 0.8424
# Chromosome 5: [1 1 0 1 1 0 1] Accuracy: 0.9742
# Chromosome 6: [1 1 1 1 1 0 1] Accuracy: 0.9924
# Chromosome 7: [1 0 1 0 1 1 1] Accuracy: 0.9833
# Chromosome 8: [1 0 1 0 0 1 1] Accuracy: 0.9258
# Chromosome 9: [1 1 1 1 0 1 1] Accuracy: 0.9788
# Chromosome 10: [1 1 1 1 1 0 0] Accuracy: 0.9561
# Chromosome 11: [1 0 1 0 1 1 1] Accuracy: 0.9833
# Chromosome 12: [0 1 0 1 1 0 1] Accuracy: 0.9803
# Chromosome 13: [0 1 0 1 1 0 1] Accuracy: 0.9803
# Chromosome 14: [1 1 1 1 1 1 1] Accuracy: 0.9894
# Chromosome 15: [1 1 0 1 1 0 1] Accuracy: 0.9742
# Chromosome 16: [0 1 0 1 0 1 1] Accuracy: 0.9091
# Chromosome 17: [1 0 1 0 0 0 1] Accuracy: 0.8424
# Chromosome 18: [0 1 1 0 0 1 1] Accuracy: 0.9091
# Chromosome 19: [0 1 0 1 1 1 1] Accuracy: 0.9818
# Chromosome 20: [0 1 1 0 1 0 1] Accuracy: 0.9682
# Chromosome 21: [1 0 1 0 0 1 1] Accuracy: 0.9258
# Chromosome 22: [0 1 0 1 1 0 1] Accuracy: 0.9803
# Chromosome 23: [1 0 1 0 0 0 1] Accuracy: 0.8424
# Chromosome 24: [1 1 1 1 1 0 0] Accuracy: 0.9561
# Chromosome 25: [1 1 1 1 1 0 1] Accuracy: 0.9924
# Chromosome 26: [0 1 0 0 1 0 1] Accuracy: 0.9455
# Chromosome 27: [1 1 0 0 1 1 1] Accuracy: 0.9621
# Chromosome 28: [1 1 1 1 1 0 1] Accuracy: 0.9924
# Chromosome 29: [0 1 1 0 1 0 1] Accuracy: 0.9682
# Chromosome 30: [1 1 1 1 0 1 1] Accuracy: 0.9788
# Chromosome 31: [1 0 1 0 1 0 1] Accuracy: 0.9727
# Chromosome 32: [1 0 1 0 1 0 1] Accuracy: 0.9727
# Chromosome 33: [1 0 1 0 0 1 1] Accuracy: 0.9258
# Chromosome 34: [0 1 0 0 0 1 1] Accuracy: 0.8106
# Chromosome 35: [1 1 0 1 1 1 1] Accuracy: 0.9848
# Chromosome 36: [1 1 0 1 1 0 1] Accuracy: 0.9742
# Chromosome 37: [0 1 0 1 1 0 1] Accuracy: 0.9803
# Chromosome 38: [0 1 0 1 1 0 1] Accuracy: 0.9803
# Chromosome 39: [1 1 1 1 0 1 1] Accuracy: 0.9788
# Chromosome 40: [0 1 0 1 1 1 1] Accuracy: 0.9818
# Chromosome 41: [0 1 1 0 1 1 0] Accuracy: 0.8848
# Chromosome 42: [1 0 1 0 1 0 1] Accuracy: 0.9727
# Chromosome 43: [0 1 1 0 1 0 1] Accuracy: 0.9682
# Chromosome 44: [0 1 0 0 0 1 1] Accuracy: 0.8106
# Chromosome 45: [1 1 1 1 1 1 1] Accuracy: 0.9894
# Chromosome 46: [1 1 1 1 0 1 1] Accuracy: 0.9788
# Chromosome 47: [1 0 1 0 1 0 1] Accuracy: 0.9727
# Chromosome 48: [1 1 1 1 1 0 1] Accuracy: 0.9924
# Chromosome 49: [1 1 1 1 1 0 0] Accuracy: 0.9561
# Chromosome 50: [0 1 0 1 1 0 1] Accuracy: 0.9803
# Best Fitness in Generation 3: 0.9924 (ID: 42)
# No improvement in generation 3. Stagnation count: 3
# Stopping early due to stagnation: No improvement for 3 generations.
# *** stack smashing detected ***: terminated

# %%
delta_t = time.time()-t
print("Time taken for total execution of serial code:", delta_t,"seconds")
serial_time = delta_t
# Out:
# Time taken for total execution of serial code: 355.65670943260193 seconds
